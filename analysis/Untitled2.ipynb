# %%
import pandas as pd

# %%
import seaborn as sns

# %%
df = pd.read_csv("../data/IBDvKEGGnorow.csv")

# %%
blues = ["red", "blue", "blue", "red", "red",
       "blue", "red", "red", "red", "red",
       "red" , "red" , "red", "red", "blue",
       "blue", "blue", "blue", "blue", "blue",
       "blue", "red", "red", "blue", "red",
       "red", "red", "red", "red", "red",
       "red", "red", "red", "blue", "blue",
       "blue", "blue", "blue", "blue", "blue",
       "red" , "blue" , "red", "blue", "red",
       "red", "red", "red", "blue", "red",
       "red", "blue", "red", "red", "red",
       "red"]

# %%
cmap = sns.cubehelix_palette(as_cmap=True, rot=-.2, light=1)

# %%
# %matplotlib inline

# %%
g = sns.clustermap(df, cmap=cmap, col_colors=blues)

# %%
df.head()
# Out:
#    CSM5LLGB  CSM6J2H9  CSM79HGR  ESM5GEYX  ESM5GEYY  ESM5GEZ1  ESM5MEAB  \
# 0  0.000000       0.0  0.000024  0.000018  0.000019  0.000000       0.0
# 1  0.000366       0.0  0.000017  0.000039  0.000014  0.000016       0.0
# 2  0.000000       0.0  0.000043  0.000000  0.000036  0.000000       0.0
# 3  0.000000       0.0  0.000019  0.000000  0.000032  0.000000       0.0
# 4  0.000000       0.0  0.000018  0.000000  0.000028  0.000000       0.0
#
#    ESM5MEB9  ESM5MEC7  ESM5MEDP    ...     PSM6XBSE  PSM6XBSG  PSM6XBTZ  \
# 0  0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.000000
# 1  0.000000  0.000037  0.000094    ...     0.000000  0.000097  0.000027
# 2  0.000000  0.000000  0.000047    ...     0.000000  0.000000  0.000070
# 3  0.000027  0.000000  0.000034    ...     0.000000  0.000000  0.000000
# 4  0.000000  0.000000  0.000000    ...     0.000026  0.000000  0.000000
#
#    PSM6XBVY  PSM7J13U  PSM7J19X  PSM7J1B3  PSM7J1BN  PSM7J1C2  PSMA2651
# ...

# %%
da = pd.read_csv("~/Desktop/data_emp_hmp.csv")

# %%
da.head()
# Out:
#         EMP     EMP.1     EMP.2     EMP.3     EMP.4     EMP.5     EMP.6  \
# 0  0.000000  0.181211  0.168103  0.209126  0.144214  0.144092  0.152412
# 1  0.181211  0.000000  0.123241  0.138828  0.129707  0.134822  0.130667
# 2  0.168103  0.123241  0.000000  0.160315  0.118545  0.112268  0.129177
# 3  0.209126  0.138828  0.160315  0.000000  0.173097  0.172177  0.166439
# 4  0.144214  0.129707  0.118545  0.173097  0.000000  0.110991  0.111555
#
#       EMP.7     EMP.8     EMP.9    ...      HMP.126   HMP.127   HMP.128  \
# 0  0.138718  0.170235  0.169847    ...     0.452970  0.421366  0.420242
# 1  0.124969  0.096492  0.125605    ...     0.420314  0.391704  0.393061
# 2  0.116618  0.099368  0.071609    ...     0.443252  0.407652  0.404688
# 3  0.167331  0.144801  0.163217    ...     0.426295  0.394621  0.392633
# 4  0.108143  0.111504  0.118166    ...     0.436185  0.405508  0.403564
#
#     HMP.129   HMP.130   HMP.131   HMP.132   HMP.133   HMP.134   HMP.135
# ...

# %%
cmap = sns.cubehelix_palette(as_cmap=True, rot=-.2, light=1)

# %%
g = sns.clustermap(da, cmap=cmap)

# %%
g = sns.clustermap(da, cmap=cmap)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set(style="whitegrid", color_codes=True)
# %matplotlib inline

# %%
df = pd.read_csv("../data/All_uniq_CRC.txt.csv")

# %%
df.head()
# Out:
#        KO    C         EC                                            Gene_ID  \
# 0  K11195  0.2  2.7.1.202                              Fructose PTS permease
# 1  K11422  0.5   2.1.1.43                 histone-lysine N-methyltransferase
# 2  K01771  1.0   4.6.1.13           1-phosphatidylinositol phosphodiesterase
# 3  K00887  1.0   2.7.1.66                                undecaprenol kinase
# 4  K04039  0.5    1.3.7.7  light-independent protochlorophyllide reductas...
#
#               State                                 Brite
# 0           Control               Carbohydrate metabolism
# 1           Control                 Amino acid metabolism
# 2           Control                 Amino acid metabolism
# 3  Advanced adenoma    Glycan biosynthesis and metabolism
# 4         Carcinoma  Metabolism of cofactors and vitamins

# %%
sns.swarmplot(x="Gene_ID", y="C", hue="State", data=df)
locs, labels = plt.xticks()
plt.setp(labels, rotation=270)
#plt.legend(loc='upper right')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
sns.swarmplot(x="Brite", y="C", hue="State", data=df)
locs, labels = plt.xticks()
plt.setp(labels, rotation=270)
#plt.legend(loc='upper right')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
df2 = pd.read_csv("../data/All_uniq_EMP.txt.csv")

# %%
df3 = pd.read_csv("../data/All_uniq_IBD.txt.csv")

# %%
df2.head()
# Out:
#        KO  Confidence_Score         EC  \
# 0  K01130               1.0    3.1.6.1
# 1  K01469               1.0    3.5.2.9
# 2  K08092               1.0  1.1.1.130
# 3  K02812               1.0  2.7.1.206
# 4  K01771               1.0   4.6.1.13
#
#                                         Gene_ID State  \
# 0                                 arylsulfatase  High
# 1              5-oxoprolinase (ATP-hydrolysing)  High
# 2          3-dehydro-L-gulonate 2-dehydrogenase  High
# 3  PTS system  sorbose-specific IIA component    High
# 4      1-phosphatidylinositol phosphodiesterase  High
#
#                                          Brite
# 0                             Lipid metabolism
# 1              Metabolism of other amino acids
# 2                      Carbohydrate metabolism
# 3   Carbohydrate metabolism/Membrane transport
# 4                      Carbohydrate metabolism

# %%
sns.swarmplot(x="Gene_ID", y="Confidence_Score", hue="State", data=df2)
locs, labels = plt.xticks()
plt.setp(labels, rotation=270)
#plt.legend(loc='upper right')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
sns.swarmplot(x="Brite", y="Confidence_Score", hue="State", data=df2)
locs, labels = plt.xticks()
plt.setp(labels, rotation=270)
#plt.legend(loc='upper right')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
sns.swarmplot(x="Gene_ID", y="Confidence_Score", hue="State", data=df3)
locs, labels = plt.xticks()
plt.setp(labels, rotation=270)
#plt.legend(loc='upper right')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
df3.head()
# Out:
#        KO  Confidence_Score        EC  \
# 0  K03382              0.25  3.5.99.3
# 1  K01500              0.25       NaN
# 2  K01522              1.00  3.6.1.29
# 3  K08710              0.25  3.5.4.42
# 4  K05394              0.25   3.8.1.8
#
#                                        Gene_ID    State  \
# 0          hydroxyatrazine ethylaminohydrolase  Healthy
# 1                                          NaN  Healthy
# 2              bis(5'-adenosyl)-triphosphatase  Healthy
# 3  N-isopropylammelide isopropylaminohydrolase  Healthy
# 4                     atrazine chlorohydrolase  Healthy
#
#                                           Brite
# 0     Xenobiotics biodegradation and metabolism
# 1                                           NaN
# 2                         Nucleotide metabolism
# 3     Xenobiotics biodegradation and metabolism
# 4     Xenobiotics biodegradation and metabolism

# %%
sns.swarmplot(x="Brite", y="Confidence_Score", hue="State", data=df3)
locs, labels = plt.xticks()
plt.setp(labels, rotation=270)
#plt.legend(loc='upper right')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
